# %%
import pandas as pd
import numpy as np

# %%
cd
# Out:
# C:\Users\Proxy1

# %%
hd=pd.read_csv("Desktop/python_67/Mall_Customers.csv")
hd
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                15.0                      39
# 1             2    Male   21                 NaN                      81
# 2             3  Female   20                16.0                       6
# 3             4  Female   23                 NaN                      77
# 4             5  Female   31                17.0                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35               120.0                      79
# 196         197  Female   45               126.0                      28
# 197         198    Male   32               126.0                      74
# 198         199    Male   32               137.0                      18
# 199         200    Male   30               137.0                      83
#
# [200 rows x 5 columns]

# %%
hd.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                15.0                      39
# 1           2    Male   21                 NaN                      81
# 2           3  Female   20                16.0                       6
# 3           4  Female   23                 NaN                      77
# 4           5  Female   31                17.0                      40

# %%
hd.tail()
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35               120.0                      79
# 196         197  Female   45               126.0                      28
# 197         198    Male   32               126.0                      74
# 198         199    Male   32               137.0                      18
# 199         200    Male   30               137.0                      83

# %%
hd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      194 non-null    float64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 7.9+ KB

# %%
hd.shape
# Out:
# (200, 5)

# %%
hd.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
hd.iloc[10:20,1:3]
# Out:
#      Genre  Age
# 10    Male   67
# 11  Female   35
# 12  Female   58
# 13  Female   24
# 14    Male   37
# 15    Male   22
# 16  Female   35
# 17    Male   20
# 18    Male   52
# 19  Female   35

# %%
hd.isnull()
# Out:
#      CustomerID  Genre    Age  Annual Income (k$)  Spending Score (1-100)
# 0         False  False  False               False                   False
# 1         False  False  False                True                   False
# 2         False  False  False               False                   False
# 3         False  False  False                True                   False
# 4         False  False  False               False                   False
# ..          ...    ...    ...                 ...                     ...
# 195       False  False  False               False                   False
# 196       False  False  False               False                   False
# 197       False  False  False               False                   False
# 198       False  False  False               False                   False
# 199       False  False  False               False                   False
#
# [200 rows x 5 columns]

# %%
hd['Annual Income (k$)']
# Out:
# 0       15.0
# 1        NaN
# 2       16.0
# 3        NaN
# 4       17.0
#        ...
# 195    120.0
# 196    126.0
# 197    126.0
# 198    137.0
# 199    137.0
# Name: Annual Income (k$), Length: 200, dtype: float64

# %%
hd['Genre'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
hd.drop_duplicates()
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                15.0                      39
# 1             2    Male   21                 NaN                      81
# 2             3  Female   20                16.0                       6
# 3             4  Female   23                 NaN                      77
# 4             5  Female   31                17.0                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35               120.0                      79
# 196         197  Female   45               126.0                      28
# 197         198    Male   32               126.0                      74
# 198         199    Male   32               137.0                      18
# 199         200    Male   30               137.0                      83
#
# [200 rows x 5 columns]

# %%
hd.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          194.000000              200.000000
# mean   100.500000   38.850000           61.788660               50.200000
# std     57.879185   13.969007           25.691306               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           43.000000               34.750000
# 50%    100.500000   36.000000           62.000000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
hd.rename(columns={"Genre":"Gender"})
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                15.0                      39
# 1             2    Male   21                 NaN                      81
# 2             3  Female   20                16.0                       6
# 3             4  Female   23                 NaN                      77
# 4             5  Female   31                17.0                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35               120.0                      79
# 196         197  Female   45               126.0                      28
# 197         198    Male   32               126.0                      74
# 198         199    Male   32               137.0                      18
# 199         200    Male   30               137.0                      83
#
# [200 rows x 5 columns]

# %%
hd['Age'].mean()
hd['Age'].mode()
# Out:
# 0    32
# Name: Age, dtype: int64

# %%
hd['Age'].median()
# Out:
# 36.0

# %%
hd['Age'].std()
# Out:
# 13.969007331558883

# %%
print(hd.isnull())
# Out:
#      CustomerID  Genre    Age  Annual Income (k$)  Spending Score (1-100)
# 0         False  False  False               False                   False
# 1         False  False  False                True                   False
# 2         False  False  False               False                   False
# 3         False  False  False                True                   False
# 4         False  False  False               False                   False
# ..          ...    ...    ...                 ...                     ...
# 195       False  False  False               False                   False
# 196       False  False  False               False                   False
# 197       False  False  False               False                   False
# 198       False  False  False               False                   False
# 199       False  False  False               False                   False
#
# [200 rows x 5 columns]

# %%
hd.fillna('null')
# Out:
#      CustomerID   Genre  Age Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19               15.0                      39
# 1             2    Male   21               null                      81
# 2             3  Female   20               16.0                       6
# 3             4  Female   23               null                      77
# 4             5  Female   31               17.0                      40
# ..          ...     ...  ...                ...                     ...
# 195         196  Female   35              120.0                      79
# 196         197  Female   45              126.0                      28
# 197         198    Male   32              126.0                      74
# 198         199    Male   32              137.0                      18
# 199         200    Male   30              137.0                      83
#
# [200 rows x 5 columns]

# %%
hd.index
# Out:
# RangeIndex(start=0, stop=200, step=1)

# %%
hd.dtypes
# Out:
# CustomerID                  int64
# Genre                      object
# Age                         int64
# Annual Income (k$)        float64
# Spending Score (1-100)      int64
# dtype: object

# %%
hd.T
# Out:
#                          0     1       2       3       4       5       6    \
# CustomerID                 1     2       3       4       5       6       7
# Genre                   Male  Male  Female  Female  Female  Female  Female
# Age                       19    21      20      23      31      22      35
# Annual Income (k$)      15.0   NaN    16.0     NaN    17.0    17.0    18.0
# Spending Score (1-100)    39    81       6      77      40      76       6
#
#                            7     8       9    ...     190     191    192  \
# CustomerID                   8     9      10  ...     191     192    193
# Genre                   Female  Male  Female  ...  Female  Female   Male
# Age                         23    64      30  ...      34      32     33
# Annual Income (k$)        18.0  19.0    19.0  ...   103.0   103.0  113.0
# Spending Score (1-100)      94     3      72  ...      23      69      8
#
#                            193     194     195     196    197    198    199
# ...

# %%
hd.T
# Out:
#                          0     1       2       3       4       5       6    \
# CustomerID                 1     2       3       4       5       6       7
# Genre                   Male  Male  Female  Female  Female  Female  Female
# Age                       19    21      20      23      31      22      35
# Annual Income (k$)      15.0   NaN    16.0     NaN    17.0    17.0    18.0
# Spending Score (1-100)    39    81       6      77      40      76       6
#
#                            7     8       9    ...     190     191    192  \
# CustomerID                   8     9      10  ...     191     192    193
# Genre                   Female  Male  Female  ...  Female  Female   Male
# Age                         23    64      30  ...      34      32     33
# Annual Income (k$)        18.0  19.0    19.0  ...   103.0   103.0  113.0
# Spending Score (1-100)      94     3      72  ...      23      69      8
#
#                            193     194     195     196    197    198    199
# ...
